# %% [markdown]
# ### Importación de datos

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd


url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# tienda2.head()
# tienda3.head()
# tienda4.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# # 1. Análisis de facturación

# %%
#Tienda 1
ingresosTienda1 = tienda['Precio'].sum()
print(f'Los ingresos de la tienda 1 son: {ingresosTienda1}')

#Tienda 2
ingresosTienda2 = tienda2['Precio'].sum()
print(f'Los ingresos de la tienda 2 son: {ingresosTienda2}')

#Tienda 3
ingresosTienda3 = tienda3['Precio'].sum()
print(f'Los ingresos de la tienda 3 son: {ingresosTienda3}')

#Tienda 4
ingresosTienda4 = tienda4['Precio'].sum()
print(f'Los ingresos de la tienda 4 son: {ingresosTienda4}')
# Out:
# Los ingresos de la tienda 1 son: 1150880400.0
# Los ingresos de la tienda 2 son: 1116343500.0
# Los ingresos de la tienda 3 son: 1098019600.0
# Los ingresos de la tienda 4 son: 1038375700.0

# %%
#grafico con matplotlib

tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ingresos = [ingresosTienda1, ingresosTienda2, ingresosTienda3, ingresosTienda4]

plt.bar(tiendas, ingresos, color=['blue', 'orange', 'green', 'red'])
plt.title('Ingresos por tienda')
plt.xlabel('Tienda')
plt.ylabel('Ingresos')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **Conclusion**
#
# La tienda con mayor ingreso es la Tienda #1 con un valor estimado de $ 1.150.880.400.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
# Cantidad de productos vendidos por categoría para cada tienda
ventas_categoria_tienda1 = tienda.groupby("Categoría del Producto").size().sort_values(ascending=False)
ventas_categoria_tienda2 = tienda2.groupby("Categoría del Producto").size().sort_values(ascending=False)
ventas_categoria_tienda3 = tienda3.groupby("Categoría del Producto").size().sort_values(ascending=False)
ventas_categoria_tienda4 = tienda4.groupby("Categoría del Producto").size().sort_values(ascending=False)

# Mostrar resultados
print("Tienda 1 - Productos vendidos por categoría:\n", ventas_categoria_tienda1, "\n")
print("Tienda 2 - Productos vendidos por categoría:\n", ventas_categoria_tienda2, "\n")
print("Tienda 3 - Productos vendidos por categoría:\n", ventas_categoria_tienda3, "\n")
print("Tienda 4 - Productos vendidos por categoría:\n", ventas_categoria_tienda4, "\n")
# Out:
# Tienda 1 - Productos vendidos por categoría:
#  Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# dtype: int64
#
# Tienda 2 - Productos vendidos por categoría:
#  Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# dtype: int64
#
# Tienda 3 - Productos vendidos por categoría:
#  Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Tus datos ya agrupados por categoría
ventas_categoria_tienda1 = tienda.groupby("Categoría del Producto").size()
ventas_categoria_tienda2 = tienda2.groupby("Categoría del Producto").size()
ventas_categoria_tienda3 = tienda3.groupby("Categoría del Producto").size()
ventas_categoria_tienda4 = tienda4.groupby("Categoría del Producto").size()

# Combinar en un solo DataFrame
df = pd.DataFrame({
    "Tienda 1": ventas_categoria_tienda1,
    "Tienda 2": ventas_categoria_tienda2,
    "Tienda 3": ventas_categoria_tienda3,
    "Tienda 4": ventas_categoria_tienda4,
}).fillna(0)  # Rellena categorías faltantes con 0

# Crear gráfico de barras agrupadas
categorias = df.index
x = np.arange(len(categorias))  # Posiciones para las categorías
ancho = 0.2  # Ancho de cada barra

plt.figure(figsize=(12, 6))
plt.bar(x - 1.5 * ancho, df["Tienda 1"], width=ancho, label="Tienda 1")
plt.bar(x - 0.5 * ancho, df["Tienda 2"], width=ancho, label="Tienda 2")
plt.bar(x + 0.5 * ancho, df["Tienda 3"], width=ancho, label="Tienda 3")
plt.bar(x + 1.5 * ancho, df["Tienda 4"], width=ancho, label="Tienda 4")

# Personalización
plt.xticks(x, categorias, rotation=45, ha="right")
plt.ylabel("Cantidad de productos vendidos")
plt.title("Productos vendidos por categoría en cada tienda")
plt.legend()
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
promedioTienda = round(tienda["Calificación"].mean(),2)
print("Tienda 1 ",promedioTienda)

promedioTienda2 = round(tienda2["Calificación"].mean(),2)
print("Tienda 2 ", promedioTienda2)

promedioTienda3 = round(tienda3["Calificación"].mean(),2)
print("Tienda 3 ",promedioTienda3)

promedioTienda4 = round(tienda4["Calificación"].mean(),2)
print("Tienda 4 ", promedioTienda2)
# Out:
# Tienda 1  3.98
# Tienda 2  4.04
# Tienda 3  4.05
# Tienda 4  4.04

# %%
# Promedios de calificación por tienda
promedios = [promedioTienda, promedioTienda2, promedioTienda3, promedioTienda4]
nombres_tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]

# Crear gráfico de barras
plt.bar(nombres_tiendas, promedios, color="orange")

# Títulos
plt.title("Calificación promedio por tienda")
plt.ylabel("Calificación")

plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Concatenar todos los dataframes en uno solo
tiendas = pd.concat([tienda, tienda2, tienda3, tienda4])

# Contar la cantidad de ventas por producto
producto_counts = tiendas['Producto'].value_counts()

# Mostrar los productos más vendidos y menos vendidos
productos_mas_vendidos = producto_counts.head(10)
productos_menos_vendidos = producto_counts.tail(10)

print("Productos más vendidos:")
print(productos_mas_vendidos)

print("\nProductos menos vendidos:")
print(productos_menos_vendidos)
# Out:
# Productos más vendidos:
# Producto
# Mesa de noche                210
# Carrito de control remoto    206
# Microondas                   206
# Batería                      203
# Cama king                    201
# Secadora de ropa             200
# Modelado predictivo          200
# Set de ollas                 200
# Cama box                     199
# Bloques de construcción      199
# Name: count, dtype: int64
#
# Productos menos vendidos:
# Producto
# Olla de presión                172
# Smartwatch                     172
# Set de vasos                   169
# Sillón                         168
# Asistente virtual              167
# Ciencia de datos con Python    166
# Guitarra eléctrica             165
# Mochila                        163
# Auriculares con micrófono      158
# Celular ABXY                   157
# Name: count, dtype: int64

# %%
# Visualizar los resultados
plt.figure(figsize=(10, 6))

# Graficar los productos más vendidos
plt.subplot(1, 2, 1)
productos_mas_vendidos.plot(kind='barh', color='g', title='Productos más vendidos')
plt.xlabel('Cantidad de ventas')

# Graficar los productos menos vendidos
plt.subplot(1, 2, 2)
productos_menos_vendidos.plot(kind='barh', color='r', title='Productos menos vendidos')
plt.xlabel('Cantidad de ventas')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
# Concatenar todos los dataframes en uno solo
tiendas = pd.concat([tienda, tienda2, tienda3, tienda4])

# Agrupar por lugar de compra (tienda) y calcular el costo de envío promedio
costo_envio_promedio = tiendas.groupby('Lugar de Compra')['Costo de envío'].mean()

# Mostrar el costo de envío promedio para cada tienda
print("Costo de envío promedio por tienda:")
print(costo_envio_promedio)
# Out:
# Costo de envío promedio por tienda:
# Lugar de Compra
# Armenia          22867.857143
# Barranquilla     22692.258065
# Bogotá           24532.082171
# Bucaramanga      26790.055249
# Cali             26726.812314
# Cartagena        22638.429752
# Cúcuta           28597.311828
# Inírida          30557.142857
# Leticia          25317.605634
# Manizales        24948.780488
# Medellín         25282.022472
# Neiva            27710.000000
# Pasto            27801.063830
# Pereira          23211.411992
# Riohacha         24127.607362
# Santa Marta      18752.317881
# Soacha           34768.421053
# Valledupar       22021.428571
# Villavicencio    25100.000000
# Name: Costo de envío, dtype: float64

# %%
# Crear un gráfico de barras para visualizar el costo de envío promedio por tienda
plt.figure(figsize=(10, 6))
costo_envio_promedio.plot(kind='bar', color='skyblue')

# Añadir títulos y etiquetas
plt.title('Costo de Envío Promedio por Tienda', fontsize=16)
plt.xlabel('Tienda', fontsize=12)
plt.ylabel('Costo de Envío Promedio', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
# Agrupar por categoría de producto y contar la cantidad de productos en cada categoría
categoria_counts = tiendas['Categoría del Producto'].value_counts()

# Gráfico de barras para la distribución de categorías de productos
plt.figure(figsize=(10, 6))
categoria_counts.plot(kind='bar', color='lightcoral')

plt.title('Distribución de Categorías de Productos', fontsize=16)
plt.xlabel('Categoría de Producto', fontsize=12)
plt.ylabel('Número de Productos', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
tiendas['Fecha de Compra'] = pd.to_datetime(tiendas['Fecha de Compra'], format='%d/%m/%Y')

ventas_por_fecha = tiendas.groupby('Fecha de Compra')['Precio'].sum()

plt.figure(figsize=(10, 6))
ventas_por_fecha.plot(kind='line', color='blue')

plt.title('Evolución de las Ventas por Fecha de Compra', fontsize=16)
plt.xlabel('Fecha de Compra', fontsize=12)
plt.ylabel('Ventas Totales (Precio)', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Gráfico de dispersión entre el precio del producto y el costo de envío
plt.figure(figsize=(10, 6))
plt.scatter(tiendas['Precio'], tiendas['Costo de envío'], color='purple', alpha=0.5)

plt.title('Relación entre Precio del Producto y Costo de Envío', fontsize=16)
plt.xlabel('Precio del Producto', fontsize=12)
plt.ylabel('Costo de Envío', fontsize=12)
plt.tight_layout()

plt.show()
